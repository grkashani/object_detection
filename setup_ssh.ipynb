# %% [markdown]
# <a href="https://colab.research.google.com/github/grkashani/object_detection/blob/master/setup_ssh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cp /content/gdrive/My\ Drive/Colab\ Notebooks/ssh_files/*.* /root/.

# %%
# !apt install xclip

# %%
# !cat /root/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... grkashani@gmail.com

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !cp -r /root/.* /content/gdrive/My\ Drive/Colab\ Notebooks/root_colab
# Out:
# cp: cannot create special file '/content/gdrive/My Drive/Colab Notebooks/root_colab/./.forever/sock/worker.1552906670046xcL.sock': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/mtab': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/os-release': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/pinentry': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/libcudnn': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/libcudnn_so': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/libcudnn_stlib': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/awk': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/nawk': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rmt': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/w': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/c++': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/c89': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/c99': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/cc': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/cpp': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/lzcat': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/lzcmp': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/lzdiff': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/lzegrep': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/lzfgrep': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/lzgrep': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/lzless': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/lzma': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/lzmore': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/unlzma': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/blas.pc-x86_64-linux-gnu': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/cblas.h-x86_64-linux-gnu': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/extcheck': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/extcheck.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/f77': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/f77.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/f95': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/f95.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/from': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/from.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/hdf5.pc': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/idlj': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/idlj.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jar': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jar.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jarsigner': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jarsigner.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/java': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/java.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/javac': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/javac.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/javadoc': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/javadoc.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/javah': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/javah.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/javap': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/javap.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jcmd': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jcmd.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jdb': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jdb.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jdeps': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jdeps.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jexec': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jexec-binfmt': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jhat': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jhat.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jinfo': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jinfo.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jjs': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jjs.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jmap': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jmap.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jps': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jps.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jrunscript': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jrunscript.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jsadebugd': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jsadebugd.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jstack': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jstack.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jstat': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jstat.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jstatd': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/jstatd.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/keytool': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/keytool.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/lapack.pc-x86_64-linux-gnu': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/libblas.a-x86_64-linux-gnu': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/libblas.so-x86_64-linux-gnu': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/libblas.so.3-x86_64-linux-gnu': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/liblapack.a-x86_64-linux-gnu': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/liblapack.so-x86_64-linux-gnu': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/liblapack.so.3-x86_64-linux-gnu': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/libmpi++.so': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/libmpi.so': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/libpsm_infinipath.so.1': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpi': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpi-c.pc': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpi-cxx.pc': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpi-fort.pc': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpi.pc': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpiCC': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpiCC.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpic++': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpic++.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpicc': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpicc.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpicxx': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpicxx.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpiexec': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpiexec.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpif77': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpif77.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpif90': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpif90.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpifort': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpifort.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpirun': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/mpirun.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/my.cnf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/native2ascii': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/native2ascii.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/orbd': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/orbd.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/pack200': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/pack200.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/pager': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/pager.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rcp': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rcp.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rename': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rename.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rlogin': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rlogin.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rmic': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rmic.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rmid': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rmid.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rmiregistry': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rmiregistry.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rsh': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/rsh.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/schemagen': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/schemagen.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/serialver': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/serialver.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/servertool': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/servertool.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/tnameserv': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/tnameserv.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/unpack200': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/unpack200.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/unrar': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/unrar.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/write': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/write.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/wsgen': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/wsgen.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/wsimport': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/wsimport.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/x-cursor-theme': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/xjc': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/alternatives/xjc.1.gz': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/dkms/template-dkms-mkdsc': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/dpkg/origins/default': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/10-antialias.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/10-hinting-slight.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/10-scale-bitmap-fonts.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/11-lcdfilter-default.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/20-unhint-small-vera.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/30-metric-aliases.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/40-nonlatin.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/45-generic.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/45-latin.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/49-sansserif.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/50-user.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/51-local.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/60-generic.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/60-latin.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/65-fonts-persian.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/65-nonlatin.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/69-unifont.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/70-no-bitmaps.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/80-delicious.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/fonts/conf.d/90-synthetic.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/localtime': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/modules-load.d/modules.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/mysql/my.cnf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/rc2.d/S01dbus': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/r
pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/E-Tugra_Certification_Authority.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/EC-ACC.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/EE_Certification_Centre_Root_CA.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/Entrust.net_Premium_2048_Secure_Server_CA.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/Entrust_Root_Certification_Authority.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/Entrust_Root_Certification_Authority_-_EC1.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/Entrust_Root_Certification_Authority_-_G2.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/GDCA_TrustAUTH_R5_ROOT.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/GeoTrust_Global_CA.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/GeoTrust_Primary_Certification_Authority.pem': Function not implemented
# ...
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/Starfield_Class_2_CA.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/Starfield_Root_Certificate_Authority_-_G2.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/Starfield_Services_Root_Certificate_Authority_-_G2.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/SwissSign_Gold_CA_-_G2.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/SwissSign_Silver_CA_-_G2.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/T-TeleSec_GlobalRoot_Class_2.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/T-TeleSec_GlobalRoot_Class_3.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/TUBITAK_Kamu_SM_SSL_Kok_Sertifikasi_-_Surum_1.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/TWCA_Global_Root_CA.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/TWCA_Root_Certification_Authority.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/Taiwan_GRCA.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/TeliaSonera_Root_CA_v1.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/TrustCor_ECA-1.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/TrustCor_RootCert_CA-1.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/TrustCor_RootCert_CA-2.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/Trustis_FPS_Root_CA.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/TÜRKTRUST_Elektronik_Sertifika_Hizmet_Sağlayıcısı_H5.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/USERTrust_ECC_Certification_Authority.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/USERTrust_RSA_Certification_Authority.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/VeriSign_Class_3_Public_Primary_Certification_Authority_-_G4.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/VeriSign_Class_3_Public_Primary_Certification_Authority_-_G5.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/VeriSign_Universal_Root_Certification_Authority.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/Verisign_Class_3_Public_Primary_Certification_Authority_-_G3.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/Visa_eCommerce_Root.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/XRamp_Global_CA_Root.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/a760e1bd.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/a94d09e5.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/ad088e1d.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/aee5f10d.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/b0e59380.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/b1159c4c.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/b1b8a7f3.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/b204d74a.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/b66938e9.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/b727005e.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/b7a5b843.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/ba89ed3b.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/c01cdfa2.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/c089bbbd.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/c0ff1f52.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/c28a8a30.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/c47d9980.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/ca6e4ad9.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/cbf06781.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/cc450945.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/cd58d51e.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/cd8c0d63.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/ce5e74ef.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/certSIGN_ROOT_CA.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/d4dae3dd.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/d6325660.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/d7e8dc79.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/d853d49e.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/dd8e9d41.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/de6d66f3.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/def36a68.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/e113c810.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/e18bfb83.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/e2799e36.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/e36a6752.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/e73d606e.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/e8de2f56.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/ePKI_Root_Certification_Authority.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/ee64a828.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/eed8c118.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/ef954a4e.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/f060240e.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/f081611a.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/f0c70a8d.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/f30dd6ad.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/f3377b1b.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/f387163d.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/f39fc864.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/fc5a8f99.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/fe8a2cd8.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/ff34af3f.0': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/thawte_Primary_Root_CA.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/thawte_Primary_Root_CA_-_G2.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/ssl/certs/thawte_Primary_Root_CA_-_G3.pem': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/sysctl.d/99-sysctl.conf': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/timers.target.wants/apt-daily-upgrade.timer': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/timers.target.wants/apt-daily.timer': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/timers.target.wants/fstrim.timer': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/timers.target.wants/motd-news.timer': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/dbus-org.freedesktop.resolve1.service': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/getty.target.wants/getty@tty1.service': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/multi-user.target.wants/ondemand.service': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/multi-user.target.wants/remote-fs.target': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/multi-user.target.wants/rsync.service': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/multi-user.target.wants/ssh.service': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/multi-user.target.wants/systemd-resolved.service': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/sshd.service': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/systemd/system/sysinit.target.wants/systemd-timesyncd.service': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/etc/xdg/systemd/user': Function not implemented
# cp: cannot create special file '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/null': Function not implemented
# cp: cannot create special file '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/random': Function not implemented
# cp: cannot create special file '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/full': Function not implemented
# cp: cannot create special file '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/tty': Function not implemented
# cp: cannot create special file '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/zero': Function not implemented
# cp: cannot create special file '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/urandom': Function not implemented
# cp: cannot create special file '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/fuse': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/ptmx': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/fd': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/stdin': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/stdout': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/stderr': Function not implemented
# cp: cannot create symbolic link '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/core': Function not implemented
# cp: cannot create special file '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/pts/ptmx': Function not implemented
# cp: cannot create special file '/content/gdrive/My Drive/Colab Notebooks/root_colab/dev/pts/1': Function not implemented
